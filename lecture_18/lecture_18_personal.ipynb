# %% [markdown]
# # <span style="color:darkblue"> Lecture 18 - Connecting to SQL via Python </span>
#
# <font size = "5">
#
# In the past lectures:
#
# - We worked directly in SQL
# - Imported data
# - Carried out basic dataset operations
#
# In  this lecture we will run SQL from Python
#
# - Combine the best of both!
# - Learn about escape characters!

# %% [markdown]
# # <span style="color:darkblue"> I. Import Libraries and Data </span>

# %% [markdown]
# <font size = "5">
#
# Import libraries

# %%
# psycogpg2 helps us process SQL commands to send to the server
# sqlalchemy facilitates establishing a connection with the server

import pandas as pd
from sqlalchemy import create_engine
from   sqlalchemy.engine import URL
from   sqlalchemy import text

# %%
pip install sqlalchemy
# Out:
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/kiwisolver-1.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/patsy-0.5.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Pillow-10.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/et_xmlfile-1.1.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Bottleneck-1.3.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/greenlet-2.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/setuptools-68.0.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/kiwisolver-1.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/patsy-0.5.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Pillow-10.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/et_xmlfile-1.1.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Bottleneck-1.3.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/greenlet-2.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/setuptools-68.0.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/packaging-23.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/fonttools-4.25.0-py3.9.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/typing_extensions-4.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/cycler-0.11.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/pip-23.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/wheel-0.41.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/pyparsing-3.0.9.dist-info due to invalid metadata entry 'name'
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.23-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages (from sqlalchemy) (4.8.0)
# Downloading SQLAlchemy-2.0.23-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 4.9 MB/s eta 0:00:0000:0100:01
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/kiwisolver-1.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/patsy-0.5.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Pillow-10.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/et_xmlfile-1.1.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Bottleneck-1.3.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/greenlet-2.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/setuptools-68.0.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/packaging-23.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/fonttools-4.25.0-py3.9.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/typing_extensions-4.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/cycler-0.11.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/pip-23.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/wheel-0.41.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/pyparsing-3.0.9.dist-info due to invalid metadata entry 'name'
# Installing collected packages: sqlalchemy
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/kiwisolver-1.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/patsy-0.5.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Pillow-10.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/et_xmlfile-1.1.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Bottleneck-1.3.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/greenlet-2.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/setuptools-68.0.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/packaging-23.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/fonttools-4.25.0-py3.9.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/typing_extensions-4.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/cycler-0.11.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/pip-23.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/wheel-0.41.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/pyparsing-3.0.9.dist-info due to invalid metadata entry 'name'
# Successfully installed sqlalchemy-2.0.23
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/kiwisolver-1.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/patsy-0.5.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Pillow-10.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/et_xmlfile-1.1.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Bottleneck-1.3.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/greenlet-2.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/setuptools-68.0.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/kiwisolver-1.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/patsy-0.5.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Pillow-10.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/et_xmlfile-1.1.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Bottleneck-1.3.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/greenlet-2.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/setuptools-68.0.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/packaging-23.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/fonttools-4.25.0-py3.9.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/typing_extensions-4.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/cycler-0.11.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/pip-23.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/kiwisolver-1.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/patsy-0.5.3-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Pillow-10.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/contourpy-1.0.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/et_xmlfile-1.1.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/Bottleneck-1.3.5.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/greenlet-2.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/setuptools-68.0.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/packaging-23.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/fonttools-4.25.0-py3.9.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/typing_extensions-4.7.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/cycler-0.11.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Users/rishikhullar/anaconda3/envs/qtm151/lib/python3.11/site-packages/pip-23.3-py3.11.egg-info due to invalid metadata entry 'name'
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <font size = "5">
#
# Import Data

# %%
# Import the two car racing datasets

results = pd.read_csv("data_raw/results.csv")
races = pd.read_csv("data_raw/races.csv")
circuits = pd.read_csv("data_raw/circuits.csv")

# %% [markdown]
# <font size = "5">
#
# Connect to SQL server

# %%
# Use the connection details to your server
# These are the default settings.
# "postgresql" is a fixed argument
# If you have a different host,database, username, or password,
# change the corresponding connection details

url_server = URL.create(
    "postgresql",
    host = 'localhost',
    database = 'formula1',
    username = 'postgres',
    port = 5432,
    password  = '12345')

connection = create_engine(url_server)
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# Cell In[5], line 15
#       1 # Use the connection details to your server
#       2 # These are the default settings.
#       3 # "postgresql" is a fixed argument
#       4 # If you have a different host,database, username, or password,
#       5 # change the corresponding connection details
#       7 url_server = URL.create(
#       8     "postgresql",
#       9     host = 'localhost',
#    (...)
#      12     port = 5432,
#      13     password  = '12345')
# ---> 15 connection = create_engine(url_server)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/create.py:552, in create_engine(url, **kwargs)
#     548 u = _url.make_url(url)
#     550 u, plugins, kwargs = u._instantiate_plugins(kwargs)
# --> 552 entrypoint = u._get_entrypoint()
#     553 _is_async = kwargs.pop("_is_async", False)
#     554 if _is_async:
#
# File ~/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/url.py:754, in URL._get_entrypoint(self)
#     752 else:
#     753     name = self.drivername.replace("+", ".")
# --> 754 cls = registry.load(name)
#     755 # check for legacy dialects that
#     756 # would return a module with 'dialect' as the
#     757 # actual class
#     758 if (
#     759     hasattr(cls, "dialect")
#     760     and isinstance(cls.dialect, type)
#     761     and issubclass(cls.dialect, Dialect)
#     762 ):
#
# File ~/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:367, in PluginLoader.load(self, name)
#     364         self.impls[name] = impl.load
#     365         return impl.load()
# --> 367 raise exc.NoSuchModuleError(
#     368     "Can't load plugin: %s:%s" % (self.group, name)
#     369 )
#
# NoSuchModuleError: Can't load plugin: sqlalchemy.dialects:postgresql

# %% [markdown]
# <font size = "5">
#
# Upload data to SQL

# %%
# Import the "results" table, with the name "results_sql"
# Con is an argument to specify the server connection
# "if_exists" is an option to replace the table if it already exists
# You can choose any name instead of "results_sql"

results.to_sql('results',
               con = connection,
               if_exists='replace',
               index=False)

# Import "races"
races.to_sql('races', 
             con = connection, 
             if_exists='replace',
             index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       1 # Import the "results" table, with the name "results_sql"
#       2 # Con is an argument to specify the server connection
#       3 # "if_exists" is an option to replace the table if it already exists
#       4 # You can choose any name instead of "results_sql"
#       6 results.to_sql('results',
# ----> 7                con = connection,
#       8                if_exists='replace',
#       9                index=False)
#      11 # Import "races"
#      12 races.to_sql('races',
#      13              con = connection,
#      14              if_exists='replace',
#      15              index=False)
#
# NameError: name 'connection' is not defined

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Upload the "circuits table" into SQL <br>
# using ".to_sql()"

# %%
# Write your own code
circuits.to_sql('circuits',
                con = connection,
                if_exists='replace',
                index=False)
# Out:
# 77

# %% [markdown]
# # <span style="color:darkblue"> II. "Escape" Characters </span>
#
# <font size = "5">
#
# - Backslash (\\) is known as an escape character
# - Used for special operations on strings
# - Great for working with text!

# %% [markdown]
# <font size = "5">
#
# Multi-line strings (" \ ")

# %%
# Use a backslash to define strins over multiple lines
# Do not include a space after "\", otherwise it won't work.
example_string = "This is a string \
                  defined over multiple lines"

# %%
example_string
# Out:
# 'This is a string                   defined over multiple lines'

# %% [markdown]
# <font size = "5">
#
# "Double quotes" inside string

# %%
# Use a backslash + quotation 

example_double = "This will \"supposedly\" put double quotes inside a string"
print(example_double)
# Out:
# This will "supposedly" put double quotes inside a string

# %% [markdown]
# <font size = "5" >
# 'Single quotes' inside string

# %%
# There is no need for a backslash given single quotes 

example_single = "This will 'supposedly' put single quotes inside a string"
print(example_single)
# Out:
# This will 'supposedly' put single quotes inside a string

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Print a string ``` SELECT "driverId" FROM results; ``` <br>
# using backslash

# %%
# Write your own code
exercise_string = "SELECT \"driverId\" FROM results;"
print(exercise_string)
#If u start with a single quotation you dont need the backslashes
# Out:
# SELECT "driverId" FROM results;

# %% [markdown]
# # <span style="color:darkblue"> III. Data operations </span>
#
# <font size = "5">
#
# - In SQL, operations are often called "queries"

# %% [markdown]
# <font size = "5">
#
# Import Data from SQL

# %%
pd.read_sql(text("SELECT * FROM results;"), connection)
#Showing from results table
#Saving as a pandas database
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# 0                1              1    10.0    58  1:34:50.616      5690616
# 1                2              2     8.0    58       +5.478      5696094
# 2                3              3     6.0    58       +8.163      5698779
# 3                4              4     5.0    58      +17.181      5707797
# 4                5              5     4.0    58      +18.014      5708630
# ...            ...            ...     ...   ...          ...          ...
# 25835           16             16     0.0    57           \N           \N
# 25836           17             17     0.0    57           \N           \N
# 25837           18             18     0.0    55           \N           \N
# 25838           19             19     0.0    55           \N           \N
# 25839            R             20     0.0    27           \N           \N
#
#       fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0             39    2       1:27.452         218.300         1
# 1             41    3       1:27.739         217.586         1
# 2             41    5       1:28.090         216.719         1
# 3             58    7       1:28.603         215.464         1
# 4             43    1       1:27.418         218.385         1
# ...          ...  ...            ...             ...       ...
# 25835         39   12       1:29.833         211.632        11
# 25836         40   20       1:31.158         208.556        11
# 25837         42   11       1:29.788         211.738         9
# 25838         45   14       1:30.309         210.517       130
# 25839         24   17       1:30.579         209.889        47
#
# [25840 rows x 18 columns]

# %%
# Use "pd.read_sql()"
# - The first argument is string with instructions wrapped in text()
#- The second argument is the server connection

# Extract all data from a column
example1 = pd.read_sql(text("SELECT * FROM results;"), connection)

# Extract a subset of columns
example2 = pd.read_sql(text("SELECT points \
                             FROM results;"), connection)

# Subset based on a string condition
example3 = pd.read_sql(text("SELECT * \
                             FROM races \
                             WHERE name = 'Abu Dhabi Grand Prix';"), connection)

# Note: (i) Remember to include "\"  to be able to define
#           strings over multiple lines
#       (ii) We can include single quotations in the WHERE command
#            without any additional escape characters

# %%
example3
# Out:
#     raceId  year  round  circuitId                  name        date  \
# 0       17  2009     17         24  Abu Dhabi Grand Prix  2009-11-01
# 1      355  2010     19         24  Abu Dhabi Grand Prix  2010-11-14
# 2      858  2011     18         24  Abu Dhabi Grand Prix  2011-11-13
# 3      877  2012     18         24  Abu Dhabi Grand Prix  2012-11-04
# 4      897  2013     17         24  Abu Dhabi Grand Prix  2013-11-03
# 5      918  2014     19         24  Abu Dhabi Grand Prix  2014-11-23
# 6      945  2015     19         24  Abu Dhabi Grand Prix  2015-11-29
# 7      968  2016     21         24  Abu Dhabi Grand Prix  2016-11-27
# 8      988  2017     20         24  Abu Dhabi Grand Prix  2017-11-26
# 9     1009  2018     21         24  Abu Dhabi Grand Prix  2018-11-25
# 10    1030  2019     21         24  Abu Dhabi Grand Prix  2019-12-01
# 11    1047  2020     17         24  Abu Dhabi Grand Prix  2020-12-13
# 12    1073  2021     22         24  Abu Dhabi Grand Prix  2021-12-12
# 13    1096  2022     22         24  Abu Dhabi Grand Prix  2022-11-20
# 14    1120  2023     23         24  Abu Dhabi Grand Prix  2023-11-26
#
#         time                                                url    fp1_date  \
# 0   11:00:00  http://en.wikipedia.org/wiki/2009_Abu_Dhabi_Gr...          \N
# 1   13:00:00  http://en.wikipedia.org/wiki/2010_Abu_Dhabi_Gr...          \N
# 2   13:00:00  http://en.wikipedia.org/wiki/2011_Abu_Dhabi_Gr...          \N
# 3   13:00:00  http://en.wikipedia.org/wiki/2012_Abu_Dhabi_Gr...          \N
# 4   13:00:00  http://en.wikipedia.org/wiki/2013_Abu_Dhabi_Gr...          \N
# 5   13:00:00  http://en.wikipedia.org/wiki/2014_Abu_Dhabi_Gr...          \N
# 6   13:00:00  http://en.wikipedia.org/wiki/2015_Abu_Dhabi_Gr...          \N
# 7   13:00:00  http://en.wikipedia.org/wiki/2016_Abu_Dhabi_Gr...          \N
# 8   13:00:00  http://en.wikipedia.org/wiki/2017_Abu_Dhabi_Gr...          \N
# 9   13:10:00  http://en.wikipedia.org/wiki/2018_Abu_Dhabi_Gr...          \N
# 10  13:10:00  http://en.wikipedia.org/wiki/2019_Abu_Dhabi_Gr...          \N
# 11  13:10:00  http://en.wikipedia.org/wiki/2020_Abu_Dhabi_Gr...          \N
# 12  13:00:00  http://en.wikipedia.org/wiki/2021_Abu_Dhabi_Gr...  2021-12-10
# 13  13:00:00  http://en.wikipedia.org/wiki/2022_Abu_Dhabi_Gr...  2022-11-18
# 14  13:00:00  https://en.wikipedia.org/wiki/2023_Abu_Dhabi_G...  2023-11-24
#
#     fp1_time    fp2_date  fp2_time    fp3_date  fp3_time  quali_date  \
# 0         \N          \N        \N          \N        \N          \N
# 1         \N          \N        \N          \N        \N          \N
# 2         \N          \N        \N          \N        \N          \N
# 3         \N          \N        \N          \N        \N          \N
# 4         \N          \N        \N          \N        \N          \N
# 5         \N          \N        \N          \N        \N          \N
# 6         \N          \N        \N          \N        \N          \N
# 7         \N          \N        \N          \N        \N          \N
# 8         \N          \N        \N          \N        \N          \N
# 9         \N          \N        \N          \N        \N          \N
# 10        \N          \N        \N          \N        \N          \N
# 11        \N          \N        \N          \N        \N          \N
# 12        \N  2021-12-10        \N  2021-12-11        \N  2021-12-11
# 13  10:00:00  2022-11-18  13:00:00  2022-11-19  11:00:00  2022-11-19
# 14  09:30:00  2023-11-24  13:00:00  2023-11-25  10:30:00  2023-11-25
#
#    quali_time sprint_date sprint_time
# 0          \N          \N          \N
# 1          \N          \N          \N
# 2          \N          \N          \N
# 3          \N          \N          \N
# 4          \N          \N          \N
# 5          \N          \N          \N
# 6          \N          \N          \N
# 7          \N          \N          \N
# 8          \N          \N          \N
# 9          \N          \N          \N
# 10         \N          \N          \N
# 11         \N          \N          \N
# 12         \N          \N          \N
# 13   14:00:00          \N          \N
# 14   14:00:00          \N          \N

# %% [markdown]
# <font size = "5">
#
# Upper case columns
#
# - In SQL syntax we use double quotes e.g. ``` "driverId" ```
# - ```.read_sql()``` requires a string inside a string
# - To do so, use escape characters, e.g.   ``` \"driverId\" ```

# %%
# Select a column
example4 = pd.read_sql(text("SELECT \"driverId\" \
                             FROM results;"), connection)

# Compute an aggregate statistic
example5 = pd.read_sql(text("SELECT AVG(points) as mean_points \
                             FROM results \
                             GROUP BY \"driverId\" ;"), connection)

# %% [markdown]
# <font size = "5">
#
# Merge two datasets

# %%
# Merge 
# Reference the column \"driverId\" with escape characters
example6 = pd.read_sql(text("SELECT * \
                             FROM results \
                             LEFT JOIN races \
                             ON results.\"raceId\" = races.\"raceId\" ;"), connection)

# Merge a subset of columns
# Use "results_sql.*" to select all columns from the primary dataset
# Use "races_sql.date" to only select the "date" column from the secondary dataset 

example7 = pd.read_sql(text("SELECT results.*, races.date \
                             FROM results \
                             LEFT JOIN races \
                             ON results.\"raceId\" = races.\"raceId\" ;"), connection)

#In second merge we are selecting all columns only from results table

# %%
example6
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  ...    fp1_date  fp1_time  \
# 0                1              1    10.0  ...          \N        \N
# 1                2              2     8.0  ...          \N        \N
# 2                3              3     6.0  ...          \N        \N
# 3                4              4     5.0  ...          \N        \N
# 4                5              5     4.0  ...          \N        \N
# ...            ...            ...     ...  ...         ...       ...
# 25835           16             16     0.0  ...  2022-11-18  10:00:00
# 25836           17             17     0.0  ...  2022-11-18  10:00:00
# 25837           18             18     0.0  ...  2022-11-18  10:00:00
# 25838           19             19     0.0  ...  2022-11-18  10:00:00
# 25839            R             20     0.0  ...  2022-11-18  10:00:00
#
#          fp2_date  fp2_time    fp3_date  fp3_time  quali_date  quali_time  \
# 0              \N        \N          \N        \N          \N          \N
# 1              \N        \N          \N        \N          \N          \N
# 2              \N        \N          \N        \N          \N          \N
# 3              \N        \N          \N        \N          \N          \N
# 4              \N        \N          \N        \N          \N          \N
# ...           ...       ...         ...       ...         ...         ...
# 25835  2022-11-18  13:00:00  2022-11-19  11:00:00  2022-11-19    14:00:00
# 25836  2022-11-18  13:00:00  2022-11-19  11:00:00  2022-11-19    14:00:00
# 25837  2022-11-18  13:00:00  2022-11-19  11:00:00  2022-11-19    14:00:00
# 25838  2022-11-18  13:00:00  2022-11-19  11:00:00  2022-11-19    14:00:00
# 25839  2022-11-18  13:00:00  2022-11-19  11:00:00  2022-11-19    14:00:00
#
#        sprint_date  sprint_time
# 0               \N           \N
# 1               \N           \N
# 2               \N           \N
# 3               \N           \N
# 4               \N           \N
# ...            ...          ...
# 25835           \N           \N
# 25836           \N           \N
# 25837           \N           \N
# 25838           \N           \N
# 25839           \N           \N
#
# [25840 rows x 36 columns]

# %%
example7
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# 0                1              1    10.0    58  1:34:50.616      5690616
# 1                2              2     8.0    58       +5.478      5696094
# 2                3              3     6.0    58       +8.163      5698779
# 3                4              4     5.0    58      +17.181      5707797
# 4                5              5     4.0    58      +18.014      5708630
# ...            ...            ...     ...   ...          ...          ...
# 25835           16             16     0.0    57           \N           \N
# 25836           17             17     0.0    57           \N           \N
# 25837           18             18     0.0    55           \N           \N
# 25838           19             19     0.0    55           \N           \N
# 25839            R             20     0.0    27           \N           \N
#
#       fastestLap rank fastestLapTime fastestLapSpeed  statusId        date
# 0             39    2       1:27.452         218.300         1  2008-03-16
# 1             41    3       1:27.739         217.586         1  2008-03-16
# 2             41    5       1:28.090         216.719         1  2008-03-16
# 3             58    7       1:28.603         215.464         1  2008-03-16
# 4             43    1       1:27.418         218.385         1  2008-03-16
# ...          ...  ...            ...             ...       ...         ...
# 25835         39   12       1:29.833         211.632        11  2022-11-20
# 25836         40   20       1:31.158         208.556        11  2022-11-20
# 25837         42   11       1:29.788         211.738         9  2022-11-20
# 25838         45   14       1:30.309         210.517       130  2022-11-20
# 25839         24   17       1:30.579         209.889        47  2022-11-20
#
# [25840 rows x 19 columns]

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Practice the ```pd.read_sql()``` command
# - FROM results compute the sum of points by <br>
# "raceId" <br>

# %%
# Write your own code
pd.read_sql(text("SELECT sum(points) AS sum_points\
                 FROM results\
                 GROUP BY \"raceId\";"), connection)
# Out:
#       sum_points
# 0           25.0
# 1           26.0
# 2           39.0
# 3          101.0
# 4          101.0
# ...          ...
# 1074        39.0
# 1075        39.0
# 1076        26.0
# 1077        24.0
# 1078        24.0
#
# [1079 rows x 1 columns]

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Practice the ```pd.read_sql()``` command
# - Merge "races_sql" and the circuits table on "circuitId" <br>
# tha you imported above using ```LEFT JOIN```

# %%
# Write your own
pd.read_sql(text("SELECT *\
                 FROM races\
                 LEFT JOIN circuits\
                 ON races.\"circuitId\" = circuits.\"circuitId\";"), connection)
# Out:
#       raceId  year  round circuitId                      name        date  \
# 0          1  2009      1         1     Australian Grand Prix  2009-03-29
# 1          2  2009      2         2      Malaysian Grand Prix  2009-04-05
# 2          3  2009      3        17        Chinese Grand Prix  2009-04-19
# 3          4  2009      4         3        Bahrain Grand Prix  2009-04-26
# 4          5  2009      5         4        Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...       ...                       ...         ...
# 1097    1116  2023     19        69  United States Grand Prix  2023-10-22
# 1098    1117  2023     20        32    Mexico City Grand Prix  2023-10-29
# 1099    1118  2023     21        18      São Paulo Grand Prix  2023-11-05
# 1100    1119  2023     22        80      Las Vegas Grand Prix  2023-11-19
# 1101    1120  2023     23        24      Abu Dhabi Grand Prix  2023-11-26
#
#           time                                                url    fp1_date  \
# 0     06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...          \N
# 1     09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...          \N
# 2     07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...          \N
# 3     12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...          \N
# 4     12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...          \N
# ...        ...                                                ...         ...
# 1097  19:00:00  https://en.wikipedia.org/wiki/2023_United_Stat...  2023-10-20
# 1098  20:00:00  https://en.wikipedia.org/wiki/2023_Mexico_City...  2023-10-27
# 1099  17:00:00  https://en.wikipedia.org/wiki/2023_S%C3%A3o_Pa...  2023-11-03
# 1100  06:00:00  https://en.wikipedia.org/wiki/2023_Las_Vegas_G...  2023-11-17
# 1101  13:00:00  https://en.wikipedia.org/wiki/2023_Abu_Dhabi_G...  2023-11-24
#
#       fp1_time  ... sprint_time circuitId   circuitRef  \
# 0           \N  ...          \N         1  albert_park
# 1           \N  ...          \N         2       sepang
# 2           \N  ...          \N        17     shanghai
# 3           \N  ...          \N         3      bahrain
# 4           \N  ...          \N         4    catalunya
# ...        ...  ...         ...       ...          ...
# 1097  17:30:00  ...    22:00:00        69     americas
# 1098  18:30:00  ...          \N        32    rodriguez
# 1099  14:30:00  ...    18:30:00        18   interlagos
# 1100  04:30:00  ...          \N        80        vegas
# 1101  09:30:00  ...          \N        24   yas_marina
#
#                                 name      location        country       lat  \
# 0     Albert Park Grand Prix Circuit     Melbourne      Australia -37.84970
# 1       Sepang International Circuit  Kuala Lumpur       Malaysia   2.76083
# 2     Shanghai International Circuit      Shanghai          China  31.33890
# 3      Bahrain International Circuit        Sakhir        Bahrain  26.03250
# 4     Circuit de Barcelona-Catalunya      Montmeló          Spain  41.57000
# ...                              ...           ...            ...       ...
# 1097         Circuit of the Americas        Austin            USA  30.13280
# 1098    Autódromo Hermanos Rodríguez   Mexico City         Mexico  19.40420
# 1099      Autódromo José Carlos Pace     São Paulo         Brazil -23.70360
# 1100  Las Vegas Strip Street Circuit     Las Vegas  United States  36.11470
# 1101              Yas Marina Circuit     Abu Dhabi            UAE  24.46720
#
#             lng   alt                                                url
# 0     144.96800    10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1     101.73800    18  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2     121.22000     5  http://en.wikipedia.org/wiki/Shanghai_Internat...
# 3      50.51060     7  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 4       2.26111   109  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...         ...   ...                                                ...
# 1097  -97.64110   161  http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# 1098  -99.09070  2227  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_He...
# 1099  -46.69970   785  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...
# 1100 -115.17300    \N  https://en.wikipedia.org/wiki/Las_Vegas_Grand_...
# 1101   54.60310     3    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
#
# [1102 rows x 27 columns]

# %% [markdown]
# # <span style="color:darkblue"> IV. Additional Material </span>
#
# <font size = "5">
#
# More about SQL syntax
#
# https://www.w3schools.com/sql/
